# %%
# =============================
# 1. Imports and Configuration
# =============================
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skimage.io import imread
from skimage.measure import label, regionprops, regionprops_table, moments_hu, shannon_entropy
from skimage.feature import local_binary_pattern
from skimage.morphology import remove_small_objects
from scipy.stats import skew, kurtosis
from scipy.spatial import Delaunay
from shapely.geometry import Polygon, MultiPoint
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Pandas display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)
pd.set_option('display.max_rows', None)

# %%
# =============================
# 2. Feature Extraction Function
# =============================
def extract_features_from_roi(roi_path, roi_crop_dir, n_fourier=3, alpha_value=0.05):
    """Extract shape, texture, and contour-based features from an ROI."""
    try:
        # Load and binarize the mask
        mask = imread(roi_path)
        mask = (mask > 0).astype(np.uint8)

        # Match corresponding grayscale crop
        crop_filename = os.path.basename(roi_path).replace("_mask.tiff", "_crop.tiff")
        crop_path = os.path.join(roi_crop_dir, crop_filename)
        if not os.path.exists(crop_path):
            print(f"Crop not found: {crop_path}")
            return None
        roi_image = imread(crop_path)

        # Label and extract shape descriptors
        labeled = label(mask)
        props_table = regionprops_table(labeled, properties=[
            'area', 'perimeter', 'eccentricity', 'solidity', 'extent',
            'orientation', 'major_axis_length', 'minor_axis_length', 'centroid'
        ])
        props = regionprops(labeled)
        if len(props) == 0:
            print("No props found.")
            return None
        region = props[0]
        convexity = region.convex_area / region.area if region.area > 0 else 0

        # Extract contour and compute Alpha Shape
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        if len(contours) == 0:
            print("No contours found.")
            return None
        contour = contours[0].squeeze()
        if contour.ndim != 2 or contour.shape[0] < 3:
            print("Invalid contour shape.")
            return None
        points = np.array(contour)

        def compute_alpha_shape(points, alpha=1.0):
            if len(points) < 4:
                return MultiPoint(points).convex_hull
            tri = Delaunay(points)
            edges = set()
            for ia, ib, ic in tri.simplices:
                pa, pb, pc = points[ia], points[ib], points[ic]
                a = np.linalg.norm(pb - pa)
                b = np.linalg.norm(pc - pb)
                c = np.linalg.norm(pa - pc)
                s = (a + b + c) / 2
                area = np.sqrt(s * (s - a) * (s - b) * (s - c))
                if area == 0:
                    continue
                circum_r = (a * b * c) / (4.0 * area)
                if circum_r < 1.0 / alpha:
                    edges.update([frozenset((ia, ib)), frozenset((ib, ic)), frozenset((ic, ia))])
            if not edges:
                return MultiPoint(points).convex_hull
            unique_indices = set(idx for edge in edges for idx in edge)
            boundary_coords = [points[idx] for idx in unique_indices]
            return Polygon(boundary_coords)

        try:
            alpha_poly = compute_alpha_shape(points, alpha=alpha_value)
            Aa = alpha_poly.area
            Pa = alpha_poly.length
            Ca = 4 * np.pi * Aa / (Pa ** 2) if Pa > 0 else 0
        except Exception as e:
            print("Alpha shape failed:", e)
            Aa, Pa, Ca = 0, 0, 0

        # Convex Hull features
        hull_points = cv2.convexHull(points)
        hull_poly = Polygon(hull_points.squeeze())
        Ah = hull_poly.area
        Ph = hull_poly.length
        Ch = 4 * np.pi * Ah / (Ph ** 2) if Ph > 0 else 0
        area_ratio = Ah / Aa if Aa > 0 else 0

        # Hu Moments (log-transformed)
        hu = moments_hu(region.moments_normalized)
        hu_log = -np.sign(hu) * np.log10(np.abs(hu) + 1e-12)

        # Fourier Descriptors
        complex_contour = contour[:, 0] + 1j * contour[:, 1]
        fourier_result = np.fft.fft(complex_contour)
        fourier_result -= fourier_result[0]
        if np.abs(fourier_result[1]) < 1e-12:
            print("Degenerate normalization factor")
            return None
        amplitudes = np.abs(fourier_result)[:n_fourier]
        phases = np.angle(fourier_result)[:n_fourier]

        # Local Binary Pattern (LBP)
        lbp = local_binary_pattern(roi_image, P=8, R=1, method="uniform")
        lbp_mean = lbp.mean()
        lbp_std = lbp.std()

        # Intensity Features
        intensity_mean = roi_image.mean()
        intensity_std = roi_image.std()
        intensity_skew = skew(roi_image.ravel())
        intensity_kurt = kurtosis(roi_image.ravel())
        intensity_entropy = shannon_entropy(roi_image)

        # Aggregate features
        data = {"filename": os.path.basename(roi_path)}
        for k, v in props_table.items():
            data[k] = v[0]
        for i, val in enumerate(hu_log):
            data[f"hu_{i+1}"] = val
        for i, val in enumerate(amplitudes):
            data[f"fd_amp_{i+1}"] = val
        for i, val in enumerate(phases):
            data[f"fd_phase_{i+1}"] = val
        data.update({
            "lbp_mean": lbp_mean,
            "lbp_std": lbp_std,
            "intensity_mean": intensity_mean,
            "intensity_std": intensity_std,
            "intensity_skew": intensity_skew,
            "intensity_kurt": intensity_kurt,
            "intensity_entropy": intensity_entropy,
            "convexity": convexity,
            "alpha_area": Aa,
            "alpha_perimeter": Pa,
            "Ca": Ca,
            "hull_area": Ah,
            "hull_perimeter": Ph,
            "Ch": Ch,
            "area_ratio": area_ratio,
        })
        return data

    except Exception as e:
        print(f"Error processing {roi_path}: {e}")
        return None

# %%
# =============================
# 3. Process All ROIs in Directory
# =============================
roi_dir = "/home/amtissot/Desktop/LIMNC/hologram_dataset_ML_project/campaigns/training_data/rois"
roi_crop_dir = "/home/amtissot/Desktop/LIMNC/hologram_dataset_ML_project/campaigns/training_data/rois_crops"

min_area = 0
max_area = np.inf
all_features = []

for fname in os.listdir(roi_dir):
    if fname.endswith(".tiff"):
        roi_path = os.path.join(roi_dir, fname)
        mask = imread(roi_path) > 0
        area = np.sum(mask)
        if min_area <= area <= max_area:
            features = extract_features_from_roi(roi_path, roi_crop_dir)
            if features:
                all_features.append(features)
                print("Processed file:", fname)
# Out:
# Processed file: 010-0790-mon_ROI_515_mask.tiff
# Processed file: 007-0845-mon_ROI_008_mask.tiff
# Processed file: 005-1035-mon_ROI_053_mask.tiff
# Processed file: 010-0896-mon_ROI_004_mask.tiff
# Processed file: 009-3347-mon_ROI_053_mask.tiff
# Processed file: 009-3229-mon_ROI_097_mask.tiff
# Processed file: 010-0119-mon_ROI_156_mask.tiff
# Processed file: 005-1071-mon_ROI_017_mask.tiff
# Processed file: 005-1228-mon_ROI_028_mask.tiff
# Processed file: 008-2972-mon_ROI_053_mask.tiff
# Processed file: 009-3220-mon_ROI_318_mask.tiff
# Processed file: 005-0447-mon_ROI_035_mask.tiff
# Processed file: 010-0790-mon_ROI_460_mask.tiff
# Processed file: 010-0790-mon_ROI_594_mask.tiff
# Processed file: 009-9654-mon_ROI_106_mask.tiff
# Processed file: 007-0173-mon_ROI_028_mask.tiff
# Processed file: 010-0790-mon_ROI_317_mask.tiff
# Processed file: 009-3266-mon_ROI_137_mask.tiff
# Processed file: 010-0119-mon_ROI_359_mask.tiff
# Processed file: 009-3337-mon_ROI_029_mask.tiff
# Processed file: 009-9703-mon_ROI_313_mask.tiff
# Processed file: 009-3193-mon_ROI_426_mask.tiff
# Processed file: 007-0258-mon_ROI_041_mask.tiff
# Processed file: 010-0073-mon_ROI_582_mask.tiff
# Processed file: 009-9752-mon_ROI_025_mask.tiff
# Processed file: 007-0211-mon_ROI_023_mask.tiff
# Processed file: 008-3038-mon_ROI_010_mask.tiff
# Processed file: 010-1053-mon_ROI_019_mask.tiff
# Processed file: 009-3229-mon_ROI_154_mask.tiff
# Processed file: 009-3304-mon_ROI_069_mask.tiff
# Processed file: 010-0073-mon_ROI_363_mask.tiff
# Processed file: 008-2935-mon_ROI_005_mask.tiff
# Processed file: 009-3193-mon_ROI_309_mask.tiff
# Processed file: 008-7473-mon_ROI_025_mask.tiff
# Processed file: 009-9752-mon_ROI_217_mask.tiff
# Processed file: 009-3193-mon_ROI_427_mask.tiff
# Processed file: 010-0790-mon_ROI_353_mask.tiff
# Processed file: 009-3193-mon_ROI_158_mask.tiff
# Processed file: 010-0790-mon_ROI_411_mask.tiff
# Processed file: 008-7481-mon_ROI_016_mask.tiff
# Processed file: 008-7524-mon_ROI_012_mask.tiff
# Processed file: 005-0250-mon_ROI_077_mask.tiff
# Processed file: 010-0073-mon_ROI_936_mask.tiff
# Processed file: 010-1053-mon_ROI_021_mask.tiff
# Processed file: 009-3220-mon_ROI_241_mask.tiff
# Processed file: 009-9703-mon_ROI_517_mask.tiff
# Processed file: 008-7684-mon_ROI_013_mask.tiff
# Processed file: 009-3202-mon_ROI_547_mask.tiff
# Processed file: 009-3193-mon_ROI_462_mask.tiff
# Processed file: 009-9703-mon_ROI_425_mask.tiff
# Processed file: 010-0119-mon_ROI_520_mask.tiff
# Processed file: 008-2940-mon_ROI_029_mask.tiff
# Processed file: 005-0361-mon_ROI_013_mask.tiff
# Processed file: 010-0790-mon_ROI_190_mask.tiff
# Processed file: 005-0250-mon_ROI_095_mask.tiff
# Processed file: 009-9703-mon_ROI_689_mask.tiff
# Processed file: 008-3453-mon_ROI_051_mask.tiff
# Processed file: 009-3220-mon_ROI_118_mask.tiff
# Processed file: 010-0073-mon_ROI_481_mask.tiff
# Processed file: 010-0073-mon_ROI_675_mask.tiff
# Processed file: 008-3340-mon_ROI_028_mask.tiff
# Processed file: 007-0084-mon_ROI_059_mask.tiff
# Processed file: 008-7425-mon_ROI_005_mask.tiff
# Processed file: 008-2940-mon_ROI_006_mask.tiff
# Processed file: 008-7568-mon_ROI_008_mask.tiff
# Processed file: 010-0073-mon_ROI_201_mask.tiff
# Processed file: 008-7564-mon_ROI_031_mask.tiff
# Processed file: 009-9752-mon_ROI_154_mask.tiff
# Processed file: 009-9703-mon_ROI_154_mask.tiff
# Processed file: 008-7476-mon_ROI_006_mask.tiff
# Processed file: 009-3266-mon_ROI_052_mask.tiff
# Processed file: 009-3196-mon_ROI_070_mask.tiff
# Processed file: 010-0073-mon_ROI_227_mask.tiff
# Processed file: 008-7524-mon_ROI_003_mask.tiff
# Processed file: 010-0896-mon_ROI_107_mask.tiff
# Processed file: 010-0119-mon_ROI_249_mask.tiff
# Processed file: 009-9752-mon_ROI_107_mask.tiff
# Processed file: 008-7568-mon_ROI_006_mask.tiff
# Processed file: 005-0250-mon_ROI_025_mask.tiff
# Processed file: 009-3193-mon_ROI_153_mask.tiff
# Processed file: 008-3346-mon_ROI_030_mask.tiff
# Processed file: 008-3332-mon_ROI_022_mask.tiff
# Processed file: 008-2940-mon_ROI_020_mask.tiff
# Processed file: 010-0790-mon_ROI_581_mask.tiff
# Processed file: 010-0790-mon_ROI_088_mask.tiff
# Processed file: 009-9703-mon_ROI_163_mask.tiff
# Processed file: 007-0287-mon_ROI_005_mask.tiff
# Processed file: 010-0073-mon_ROI_597_mask.tiff
# Processed file: 005-0576-mon_ROI_082_mask.tiff
# Processed file: 010-0790-mon_ROI_731_mask.tiff
# Processed file: 008-3453-mon_ROI_003_mask.tiff
# Processed file: 005-0804-mon_ROI_061_mask.tiff
# Processed file: 010-0073-mon_ROI_644_mask.tiff
# Processed file: 010-0505-mon_ROI_271_mask.tiff
# Processed file: 010-0790-mon_ROI_707_mask.tiff
# Processed file: 008-3094-mon_ROI_065_mask.tiff
# Processed file: 007-0258-mon_ROI_042_mask.tiff
# Processed file: 008-3038-mon_ROI_048_mask.tiff
# Processed file: 005-0354-mon_ROI_037_mask.tiff
# Processed file: 010-0999-mon_ROI_048_mask.tiff
# Processed file: 010-0790-mon_ROI_201_mask.tiff
# Processed file: 005-0854-mon_ROI_113_mask.tiff
# Processed file: 010-0073-mon_ROI_950_mask.tiff
# Processed file: 010-0119-mon_ROI_480_mask.tiff
# Processed file: 008-7681-mon_ROI_026_mask.tiff
# Processed file: 009-3295-mon_ROI_031_mask.tiff
# Processed file: 009-3266-mon_ROI_068_mask.tiff
# Processed file: 009-9703-mon_ROI_034_mask.tiff
# Processed file: 009-3304-mon_ROI_008_mask.tiff
# Processed file: 009-3196-mon_ROI_362_mask.tiff
# Processed file: 009-3220-mon_ROI_113_mask.tiff
# Processed file: 008-3148-mon_ROI_010_mask.tiff
# Processed file: 010-0790-mon_ROI_170_mask.tiff
# Processed file: 005-0250-mon_ROI_072_mask.tiff
# Processed file: 008-2940-mon_ROI_033_mask.tiff
# Processed file: 010-0073-mon_ROI_216_mask.tiff
# Processed file: 009-3202-mon_ROI_587_mask.tiff
# Processed file: 008-3148-mon_ROI_003_mask.tiff
# Processed file: 009-3247-mon_ROI_120_mask.tiff
# Processed file: 010-0073-mon_ROI_373_mask.tiff
# Processed file: 008-7515-mon_ROI_037_mask.tiff
# Processed file: 007-0360-mon_ROI_031_mask.tiff
# Processed file: 005-0250-mon_ROI_219_mask.tiff
# Processed file: 009-3337-mon_ROI_028_mask.tiff
# Processed file: 010-0505-mon_ROI_263_mask.tiff
# Processed file: 010-0073-mon_ROI_771_mask.tiff
# Processed file: 009-3196-mon_ROI_371_mask.tiff
# Processed file: 009-3196-mon_ROI_331_mask.tiff
# Processed file: 010-0073-mon_ROI_160_mask.tiff
# Processed file: 010-0119-mon_ROI_313_mask.tiff
# Processed file: 010-1239-mon_ROI_101_mask.tiff
# Processed file: 009-3347-mon_ROI_045_mask.tiff
# Processed file: 010-0896-mon_ROI_031_mask.tiff
# Processed file: 009-3196-mon_ROI_069_mask.tiff
# Processed file: 010-1208-mon_ROI_032_mask.tiff
# Processed file: 005-1071-mon_ROI_031_mask.tiff
# Processed file: 008-7473-mon_ROI_003_mask.tiff
# Processed file: 010-0119-mon_ROI_624_mask.tiff
# Processed file: 009-3202-mon_ROI_408_mask.tiff
# Processed file: 010-0073-mon_ROI_449_mask.tiff
# Processed file: 009-3398-mon_ROI_010_mask.tiff
# Processed file: 010-0505-mon_ROI_082_mask.tiff
# Processed file: 008-3230-mon_ROI_006_mask.tiff
# Processed file: 009-9703-mon_ROI_171_mask.tiff
# Processed file: 009-3196-mon_ROI_338_mask.tiff
# Processed file: 007-0912-mon_ROI_008_mask.tiff
# Processed file: 009-3247-mon_ROI_116_mask.tiff
# Processed file: 008-3094-mon_ROI_034_mask.tiff
# Processed file: 010-0790-mon_ROI_486_mask.tiff
# Processed file: 009-9752-mon_ROI_269_mask.tiff
# Processed file: 005-0836-mon_ROI_000_mask.tiff
# Processed file: 010-0790-mon_ROI_188_mask.tiff
# Processed file: 009-9703-mon_ROI_280_mask.tiff
# Processed file: 009-9752-mon_ROI_228_mask.tiff
# Processed file: 009-9752-mon_ROI_099_mask.tiff
# Processed file: 009-3247-mon_ROI_088_mask.tiff
# Processed file: 009-3527-mon_ROI_004_mask.tiff
# Processed file: 009-3295-mon_ROI_098_mask.tiff
# Processed file: 009-3193-mon_ROI_301_mask.tiff
# Processed file: 009-3347-mon_ROI_043_mask.tiff
# Processed file: 009-3196-mon_ROI_388_mask.tiff
# Processed file: 008-7429-mon_ROI_031_mask.tiff
# Processed file: 009-3220-mon_ROI_060_mask.tiff
# Processed file: 009-3398-mon_ROI_045_mask.tiff
# Processed file: 010-0790-mon_ROI_718_mask.tiff
# Processed file: 009-3398-mon_ROI_066_mask.tiff
# Processed file: 009-3220-mon_ROI_249_mask.tiff
# Processed file: 005-0405-mon_ROI_066_mask.tiff
# Processed file: 009-3266-mon_ROI_206_mask.tiff
# Processed file: 009-3196-mon_ROI_061_mask.tiff
# Processed file: 010-0073-mon_ROI_611_mask.tiff
# Processed file: 008-3094-mon_ROI_000_mask.tiff
# Processed file: 008-3207-mon_ROI_035_mask.tiff
# Processed file: 007-0137-mon_ROI_034_mask.tiff
# Processed file: 005-0250-mon_ROI_120_mask.tiff
# Processed file: 009-3229-mon_ROI_014_mask.tiff
# Processed file: 005-1035-mon_ROI_012_mask.tiff
# Processed file: 009-9703-mon_ROI_695_mask.tiff
# Processed file: 009-3220-mon_ROI_440_mask.tiff
# Processed file: 010-1461-mon_ROI_034_mask.tiff
# Processed file: 010-0947-mon_ROI_043_mask.tiff
# Processed file: 010-0073-mon_ROI_393_mask.tiff
# Processed file: 007-0137-mon_ROI_056_mask.tiff
# Processed file: 009-3193-mon_ROI_141_mask.tiff
# Processed file: 010-0119-mon_ROI_296_mask.tiff
# Processed file: 010-0073-mon_ROI_548_mask.tiff
# Processed file: 009-3406-mon_ROI_037_mask.tiff
# Processed file: 007-0287-mon_ROI_025_mask.tiff
# Processed file: 010-1208-mon_ROI_066_mask.tiff
# Processed file: 010-1471-mon_ROI_008_mask.tiff
# Processed file: 008-3088-mon_ROI_003_mask.tiff
# Processed file: 010-0790-mon_ROI_510_mask.tiff
# Processed file: 010-0790-mon_ROI_410_mask.tiff
# Processed file: 009-3202-mon_ROI_584_mask.tiff
# Processed file: 010-0896-mon_ROI_065_mask.tiff
# Processed file: 009-3337-mon_ROI_081_mask.tiff
# Processed file: 008-2940-mon_ROI_024_mask.tiff
# Processed file: 010-0073-mon_ROI_652_mask.tiff
# Processed file: 010-0505-mon_ROI_319_mask.tiff
# Processed file: 009-9703-mon_ROI_202_mask.tiff
# Processed file: 009-3196-mon_ROI_312_mask.tiff
# Processed file: 009-3202-mon_ROI_536_mask.tiff
# Processed file: 008-7481-mon_ROI_005_mask.tiff
# Processed file: 009-9703-mon_ROI_254_mask.tiff
# Processed file: 010-0790-mon_ROI_111_mask.tiff
# Processed file: 005-0854-mon_ROI_052_mask.tiff
# Processed file: 009-9654-mon_ROI_056_mask.tiff
# Processed file: 009-3196-mon_ROI_179_mask.tiff
# Processed file: 009-3247-mon_ROI_109_mask.tiff
# Processed file: 007-0137-mon_ROI_049_mask.tiff
# Processed file: 010-0505-mon_ROI_053_mask.tiff
# Processed file: 009-3343-mon_ROI_041_mask.tiff
# Processed file: 009-3193-mon_ROI_450_mask.tiff
# Processed file: 008-3453-mon_ROI_020_mask.tiff
# Processed file: 009-3410-mon_ROI_051_mask.tiff
# Processed file: 010-0790-mon_ROI_027_mask.tiff
# Processed file: 009-3247-mon_ROI_011_mask.tiff
# Processed file: 005-1035-mon_ROI_044_mask.tiff
# Processed file: 009-3220-mon_ROI_157_mask.tiff
# Processed file: 005-0447-mon_ROI_069_mask.tiff
# Processed file: 008-3456-mon_ROI_007_mask.tiff
# Processed file: 005-0836-mon_ROI_010_mask.tiff
# Processed file: 010-0999-mon_ROI_029_mask.tiff
# Processed file: 008-7433-mon_ROI_015_mask.tiff
# Processed file: 005-0886-mon_ROI_001_mask.tiff
# Processed file: 005-0886-mon_ROI_077_mask.tiff
# Processed file: 010-0790-mon_ROI_200_mask.tiff
# Processed file: 009-3337-mon_ROI_065_mask.tiff
# Processed file: 009-3532-mon_ROI_003_mask.tiff
# Processed file: 009-3343-mon_ROI_026_mask.tiff
# Processed file: 009-9703-mon_ROI_431_mask.tiff
# Processed file: 009-3229-mon_ROI_016_mask.tiff
# Processed file: 009-9703-mon_ROI_644_mask.tiff
# Processed file: 009-3193-mon_ROI_110_mask.tiff
# Processed file: 009-9703-mon_ROI_010_mask.tiff
# Processed file: 010-0119-mon_ROI_442_mask.tiff
# Processed file: 008-2972-mon_ROI_067_mask.tiff
# Processed file: 010-0119-mon_ROI_219_mask.tiff
# Processed file: 009-9703-mon_ROI_006_mask.tiff
# Processed file: 005-1071-mon_ROI_059_mask.tiff
# Processed file: 009-3202-mon_ROI_642_mask.tiff
# Processed file: 008-7681-mon_ROI_014_mask.tiff
# Processed file: 010-0073-mon_ROI_055_mask.tiff
# Processed file: 010-0119-mon_ROI_298_mask.tiff
# Processed file: 008-2980-mon_ROI_007_mask.tiff
# Processed file: 005-0354-mon_ROI_005_mask.tiff
# Processed file: 010-1461-mon_ROI_050_mask.tiff
# Processed file: 009-9703-mon_ROI_231_mask.tiff
# Processed file: 009-3202-mon_ROI_030_mask.tiff
# Processed file: 007-0876-mon_ROI_018_mask.tiff
# Processed file: 009-9703-mon_ROI_568_mask.tiff
# Processed file: 007-1035-mon_ROI_017_mask.tiff
# Processed file: 010-0119-mon_ROI_232_mask.tiff
# Processed file: 009-3343-mon_ROI_033_mask.tiff
# Processed file: 008-7425-mon_ROI_014_mask.tiff
# Processed file: 008-7433-mon_ROI_003_mask.tiff
# Processed file: 010-0119-mon_ROI_343_mask.tiff
# Processed file: 010-0119-mon_ROI_319_mask.tiff
# Processed file: 010-0119-mon_ROI_270_mask.tiff
# Processed file: 009-9703-mon_ROI_068_mask.tiff
# Processed file: 008-7564-mon_ROI_014_mask.tiff
# Processed file: 005-0405-mon_ROI_101_mask.tiff
# Processed file: 008-2972-mon_ROI_034_mask.tiff
# Processed file: 009-9703-mon_ROI_531_mask.tiff
# Processed file: 009-3193-mon_ROI_080_mask.tiff
# Processed file: 009-9752-mon_ROI_215_mask.tiff
# Processed file: 005-0250-mon_ROI_132_mask.tiff
# Processed file: 009-3202-mon_ROI_628_mask.tiff
# Processed file: 010-0790-mon_ROI_173_mask.tiff
# Processed file: 005-0886-mon_ROI_041_mask.tiff
# Processed file: 009-9703-mon_ROI_518_mask.tiff
# Processed file: 010-0119-mon_ROI_174_mask.tiff
# Processed file: 010-0505-mon_ROI_307_mask.tiff
# Processed file: 005-0354-mon_ROI_084_mask.tiff
# Processed file: 010-0073-mon_ROI_981_mask.tiff
# Processed file: 009-9752-mon_ROI_153_mask.tiff
# Processed file: 008-7425-mon_ROI_011_mask.tiff
# Processed file: 010-0073-mon_ROI_890_mask.tiff
# Processed file: 005-1062-mon_ROI_037_mask.tiff
# Processed file: 008-7429-mon_ROI_071_mask.tiff
# Processed file: 007-0211-mon_ROI_034_mask.tiff
# Processed file: 010-1239-mon_ROI_025_mask.tiff
# Processed file: 009-3410-mon_ROI_044_mask.tiff
# Processed file: 009-3196-mon_ROI_047_mask.tiff
# Processed file: 010-0119-mon_ROI_496_mask.tiff
# Processed file: 010-0505-mon_ROI_389_mask.tiff
# Processed file: 008-7681-mon_ROI_000_mask.tiff
# Processed file: 010-0073-mon_ROI_563_mask.tiff
# Processed file: 008-3466-mon_ROI_000_mask.tiff
# Processed file: 008-3466-mon_ROI_005_mask.tiff
# Processed file: 009-3202-mon_ROI_051_mask.tiff
# Processed file: 009-3220-mon_ROI_259_mask.tiff
# Processed file: 010-0505-mon_ROI_278_mask.tiff
# Processed file: 009-9703-mon_ROI_240_mask.tiff
# Processed file: 009-3220-mon_ROI_239_mask.tiff
# Processed file: 010-0073-mon_ROI_018_mask.tiff
# Processed file: 010-0073-mon_ROI_480_mask.tiff
# Processed file: 009-3196-mon_ROI_222_mask.tiff
# Processed file: 008-3207-mon_ROI_066_mask.tiff
# Processed file: 010-0505-mon_ROI_364_mask.tiff
# Processed file: 010-0073-mon_ROI_470_mask.tiff
# Processed file: 009-3220-mon_ROI_293_mask.tiff
# Processed file: 005-0576-mon_ROI_106_mask.tiff
# Processed file: 010-0073-mon_ROI_501_mask.tiff
# Processed file: 008-3466-mon_ROI_004_mask.tiff
# Processed file: 010-0073-mon_ROI_651_mask.tiff
# Processed file: 010-0073-mon_ROI_242_mask.tiff
# Processed file: 009-3196-mon_ROI_238_mask.tiff
# Processed file: 010-0073-mon_ROI_874_mask.tiff
# Processed file: 009-3220-mon_ROI_134_mask.tiff
# Processed file: 009-3202-mon_ROI_657_mask.tiff
# Processed file: 009-3193-mon_ROI_431_mask.tiff
# Processed file: 008-3346-mon_ROI_006_mask.tiff
# Processed file: 009-3220-mon_ROI_004_mask.tiff
# Processed file: 010-0119-mon_ROI_536_mask.tiff
# Processed file: 009-3193-mon_ROI_022_mask.tiff
# Processed file: 008-3038-mon_ROI_018_mask.tiff
# Processed file: 007-0137-mon_ROI_065_mask.tiff
# Processed file: 009-3196-mon_ROI_407_mask.tiff
# Processed file: 009-3202-mon_ROI_302_mask.tiff
# Processed file: 010-0119-mon_ROI_019_mask.tiff
# Processed file: 005-1035-mon_ROI_025_mask.tiff
# Processed file: 008-3453-mon_ROI_049_mask.tiff
# Processed file: 009-3202-mon_ROI_369_mask.tiff
# Processed file: 005-0854-mon_ROI_041_mask.tiff
# Processed file: 009-9703-mon_ROI_053_mask.tiff
# Processed file: 005-1071-mon_ROI_067_mask.tiff
# Processed file: 009-3202-mon_ROI_509_mask.tiff
# Processed file: 005-0250-mon_ROI_147_mask.tiff
# Processed file: 009-3247-mon_ROI_142_mask.tiff
# Processed file: 009-9703-mon_ROI_469_mask.tiff
# Processed file: 009-3295-mon_ROI_133_mask.tiff
# Processed file: 008-7481-mon_ROI_039_mask.tiff
# Processed file: 005-0576-mon_ROI_021_mask.tiff
# Processed file: 010-1239-mon_ROI_050_mask.tiff
# Processed file: 009-9752-mon_ROI_016_mask.tiff
# Processed file: 010-0790-mon_ROI_649_mask.tiff
# Processed file: 010-0073-mon_ROI_198_mask.tiff
# Processed file: 008-2980-mon_ROI_019_mask.tiff
# Processed file: 005-0576-mon_ROI_095_mask.tiff
# Processed file: 005-0250-mon_ROI_071_mask.tiff
# Processed file: 009-3193-mon_ROI_188_mask.tiff
# Processed file: 010-1008-mon_ROI_067_mask.tiff
# Processed file: 010-0073-mon_ROI_472_mask.tiff
# Processed file: 009-3202-mon_ROI_146_mask.tiff
# Processed file: 010-1424-mon_ROI_008_mask.tiff
# Processed file: 005-0836-mon_ROI_006_mask.tiff
# Processed file: 010-0073-mon_ROI_021_mask.tiff
# Processed file: 009-9703-mon_ROI_761_mask.tiff
# Processed file: 009-9752-mon_ROI_112_mask.tiff
# Processed file: 008-3207-mon_ROI_075_mask.tiff
# Processed file: 009-9752-mon_ROI_280_mask.tiff
# Processed file: 009-3229-mon_ROI_062_mask.tiff
# Processed file: 010-0119-mon_ROI_640_mask.tiff
# Processed file: 008-3466-mon_ROI_022_mask.tiff
# Processed file: 009-3202-mon_ROI_276_mask.tiff
# Processed file: 007-0137-mon_ROI_077_mask.tiff
# Processed file: 009-3247-mon_ROI_094_mask.tiff
# Processed file: 010-0505-mon_ROI_164_mask.tiff
# Processed file: 007-0845-mon_ROI_020_mask.tiff
# Processed file: 008-3038-mon_ROI_059_mask.tiff
# Processed file: 010-1424-mon_ROI_040_mask.tiff
# Processed file: 010-0119-mon_ROI_412_mask.tiff
# Processed file: 010-0790-mon_ROI_482_mask.tiff
# Processed file: 008-7524-mon_ROI_044_mask.tiff
# Processed file: 005-0707-mon_ROI_037_mask.tiff
# Processed file: 005-0447-mon_ROI_045_mask.tiff
# Processed file: 009-3196-mon_ROI_587_mask.tiff
# Processed file: 009-3337-mon_ROI_043_mask.tiff
# Processed file: 009-3406-mon_ROI_045_mask.tiff
# Processed file: 005-0354-mon_ROI_026_mask.tiff
# Processed file: 008-2913-mon_ROI_013_mask.tiff
# Processed file: 008-2913-mon_ROI_059_mask.tiff
# Processed file: 009-3202-mon_ROI_374_mask.tiff
# Processed file: 010-0073-mon_ROI_203_mask.tiff
# Processed file: 005-0405-mon_ROI_047_mask.tiff
# Processed file: 009-3193-mon_ROI_341_mask.tiff
# Processed file: 009-3220-mon_ROI_514_mask.tiff
# Processed file: 010-0505-mon_ROI_383_mask.tiff
# Processed file: 005-1062-mon_ROI_041_mask.tiff
# Processed file: 010-0896-mon_ROI_131_mask.tiff
# Processed file: 009-3247-mon_ROI_153_mask.tiff
# Processed file: 010-0790-mon_ROI_576_mask.tiff
# Processed file: 009-3337-mon_ROI_052_mask.tiff
# Processed file: 005-1213-mon_ROI_021_mask.tiff
# Processed file: 009-3247-mon_ROI_111_mask.tiff
# Processed file: 009-3196-mon_ROI_100_mask.tiff
# Processed file: 008-2935-mon_ROI_024_mask.tiff
# Processed file: 009-3196-mon_ROI_509_mask.tiff
# Processed file: 010-0073-mon_ROI_218_mask.tiff
# Processed file: 005-0250-mon_ROI_011_mask.tiff
# Processed file: 010-0790-mon_ROI_564_mask.tiff
# Processed file: 007-0084-mon_ROI_003_mask.tiff
# Processed file: 010-0505-mon_ROI_095_mask.tiff
# Processed file: 008-2913-mon_ROI_040_mask.tiff
# Processed file: 010-0790-mon_ROI_517_mask.tiff
# Processed file: 008-3453-mon_ROI_030_mask.tiff
# Processed file: 010-0505-mon_ROI_169_mask.tiff
# Processed file: 005-0354-mon_ROI_002_mask.tiff
# Processed file: 005-1228-mon_ROI_010_mask.tiff
# Processed file: 010-0119-mon_ROI_130_mask.tiff
# Processed file: 009-3202-mon_ROI_158_mask.tiff
# Processed file: 009-9752-mon_ROI_116_mask.tiff
# Processed file: 008-3453-mon_ROI_043_mask.tiff
# Processed file: 007-0408-mon_ROI_002_mask.tiff
# Processed file: 005-0447-mon_ROI_073_mask.tiff
# Processed file: 010-0947-mon_ROI_054_mask.tiff
# Processed file: 009-3202-mon_ROI_514_mask.tiff
# Processed file: 009-9703-mon_ROI_429_mask.tiff
# Processed file: 009-3202-mon_ROI_039_mask.tiff
# Processed file: 008-3346-mon_ROI_016_mask.tiff
# Processed file: 007-0295-mon_ROI_004_mask.tiff
# Processed file: 007-0084-mon_ROI_053_mask.tiff
# Processed file: 008-3230-mon_ROI_004_mask.tiff
# Processed file: 010-0896-mon_ROI_108_mask.tiff
# Processed file: 007-0258-mon_ROI_049_mask.tiff
# Processed file: 005-0447-mon_ROI_148_mask.tiff
# Processed file: 010-1208-mon_ROI_009_mask.tiff
# Processed file: 010-0073-mon_ROI_487_mask.tiff
# Processed file: 009-3196-mon_ROI_536_mask.tiff
# Processed file: 009-9752-mon_ROI_069_mask.tiff
# Processed file: 007-0876-mon_ROI_013_mask.tiff
# Processed file: 010-1199-mon_ROI_006_mask.tiff
# Processed file: 010-1471-mon_ROI_034_mask.tiff
# Processed file: 010-0790-mon_ROI_052_mask.tiff
# Processed file: 008-7515-mon_ROI_016_mask.tiff
# Processed file: 005-0405-mon_ROI_020_mask.tiff
# Processed file: 009-3193-mon_ROI_194_mask.tiff
# Processed file: 005-0886-mon_ROI_071_mask.tiff
# Processed file: 008-2980-mon_ROI_029_mask.tiff
# Processed file: 010-1199-mon_ROI_021_mask.tiff
# Processed file: 009-3220-mon_ROI_193_mask.tiff
# Processed file: 005-0576-mon_ROI_055_mask.tiff
# Processed file: 009-3229-mon_ROI_106_mask.tiff
# Processed file: 010-1424-mon_ROI_010_mask.tiff
# Processed file: 009-3247-mon_ROI_021_mask.tiff
# Processed file: 008-3148-mon_ROI_046_mask.tiff
# Processed file: 005-0576-mon_ROI_037_mask.tiff
# Processed file: 010-0790-mon_ROI_366_mask.tiff
# Processed file: 005-0447-mon_ROI_151_mask.tiff
# Processed file: 008-3346-mon_ROI_020_mask.tiff
# Processed file: 008-3212-mon_ROI_007_mask.tiff
# Processed file: 009-3410-mon_ROI_055_mask.tiff
# Processed file: 010-0790-mon_ROI_706_mask.tiff
# Processed file: 005-0886-mon_ROI_022_mask.tiff
# Processed file: 005-0250-mon_ROI_266_mask.tiff
# Processed file: 008-3340-mon_ROI_019_mask.tiff
# Processed file: 010-1424-mon_ROI_033_mask.tiff
# Processed file: 008-2913-mon_ROI_054_mask.tiff
# Processed file: 009-3196-mon_ROI_072_mask.tiff
# Processed file: 009-3220-mon_ROI_198_mask.tiff
# Processed file: 009-3202-mon_ROI_344_mask.tiff
# Processed file: 009-9703-mon_ROI_532_mask.tiff
# Processed file: 009-3295-mon_ROI_051_mask.tiff
# Processed file: 010-0073-mon_ROI_629_mask.tiff
# Processed file: 009-3196-mon_ROI_265_mask.tiff
# Processed file: 010-0119-mon_ROI_532_mask.tiff
# Processed file: 008-3207-mon_ROI_040_mask.tiff
# Processed file: 010-0073-mon_ROI_617_mask.tiff
# Processed file: 010-0073-mon_ROI_341_mask.tiff
# Processed file: 007-0137-mon_ROI_073_mask.tiff
# Processed file: 009-3295-mon_ROI_005_mask.tiff
# Processed file: 005-0804-mon_ROI_068_mask.tiff
# Processed file: 009-9703-mon_ROI_405_mask.tiff
# Processed file: 010-0073-mon_ROI_392_mask.tiff
# Processed file: 009-3202-mon_ROI_037_mask.tiff
# Processed file: 010-0119-mon_ROI_382_mask.tiff
# Processed file: 009-9703-mon_ROI_382_mask.tiff
# Processed file: 010-1053-mon_ROI_004_mask.tiff
# Processed file: 005-1035-mon_ROI_042_mask.tiff
# Processed file: 009-3196-mon_ROI_233_mask.tiff
# Processed file: 009-3398-mon_ROI_008_mask.tiff
# Processed file: 005-0250-mon_ROI_089_mask.tiff
# Processed file: 009-3196-mon_ROI_021_mask.tiff
# Processed file: 009-3266-mon_ROI_115_mask.tiff
# Processed file: 008-3453-mon_ROI_041_mask.tiff
# Processed file: 007-0173-mon_ROI_029_mask.tiff
# Processed file: 010-1471-mon_ROI_029_mask.tiff
# Processed file: 010-0073-mon_ROI_901_mask.tiff
# Processed file: 009-3229-mon_ROI_041_mask.tiff
# Processed file: 010-0505-mon_ROI_149_mask.tiff
# Processed file: 009-3202-mon_ROI_656_mask.tiff
# Processed file: 008-3453-mon_ROI_061_mask.tiff
# Processed file: 008-3453-mon_ROI_014_mask.tiff
# Processed file: 005-0250-mon_ROI_060_mask.tiff
# Processed file: 009-3266-mon_ROI_008_mask.tiff
# Processed file: 005-0309-mon_ROI_111_mask.tiff
# Processed file: 007-0258-mon_ROI_032_mask.tiff
# Processed file: 007-1042-mon_ROI_003_mask.tiff
# Processed file: 010-0073-mon_ROI_325_mask.tiff
# Processed file: 009-3193-mon_ROI_433_mask.tiff
# Processed file: 009-3196-mon_ROI_219_mask.tiff
# Processed file: 009-3202-mon_ROI_588_mask.tiff
# Processed file: 009-3247-mon_ROI_115_mask.tiff
# Processed file: 010-1424-mon_ROI_014_mask.tiff
# Processed file: 010-0790-mon_ROI_082_mask.tiff
# Processed file: 009-3202-mon_ROI_378_mask.tiff
# Processed file: 010-0790-mon_ROI_577_mask.tiff
# Processed file: 009-3196-mon_ROI_457_mask.tiff
# Processed file: 009-3202-mon_ROI_142_mask.tiff
# Processed file: 010-0896-mon_ROI_132_mask.tiff
# Processed file: 007-0528-mon_ROI_033_mask.tiff
# Processed file: 009-3196-mon_ROI_183_mask.tiff
# Processed file: 005-0354-mon_ROI_089_mask.tiff
# Processed file: 008-3230-mon_ROI_021_mask.tiff
# Processed file: 009-3196-mon_ROI_372_mask.tiff
# Processed file: 010-0896-mon_ROI_127_mask.tiff
# Processed file: 009-3337-mon_ROI_071_mask.tiff
# Processed file: 010-0119-mon_ROI_379_mask.tiff
# Processed file: 009-3220-mon_ROI_125_mask.tiff
# Processed file: 010-0073-mon_ROI_887_mask.tiff
# Processed file: 005-0250-mon_ROI_225_mask.tiff
# Processed file: 009-3410-mon_ROI_021_mask.tiff
# Processed file: 010-0505-mon_ROI_212_mask.tiff
# Processed file: 009-3220-mon_ROI_382_mask.tiff
# Processed file: 009-3406-mon_ROI_052_mask.tiff
# Processed file: 010-0073-mon_ROI_658_mask.tiff
# Processed file: 009-3202-mon_ROI_377_mask.tiff
# Processed file: 007-0211-mon_ROI_031_mask.tiff
# Processed file: 005-0707-mon_ROI_023_mask.tiff
# Processed file: 005-0405-mon_ROI_042_mask.tiff
# Processed file: 009-3220-mon_ROI_451_mask.tiff
# Processed file: 010-0505-mon_ROI_258_mask.tiff
# Processed file: 005-0804-mon_ROI_000_mask.tiff
# Processed file: 010-0119-mon_ROI_637_mask.tiff
# Processed file: 009-3196-mon_ROI_254_mask.tiff
# Processed file: 010-0790-mon_ROI_568_mask.tiff
# Processed file: 010-0073-mon_ROI_804_mask.tiff
# Processed file: 010-0073-mon_ROI_799_mask.tiff
# Processed file: 010-0119-mon_ROI_005_mask.tiff
# Processed file: 008-2980-mon_ROI_027_mask.tiff
# Processed file: 005-0405-mon_ROI_087_mask.tiff
# Processed file: 010-0073-mon_ROI_710_mask.tiff
# Processed file: 009-3193-mon_ROI_191_mask.tiff
# Processed file: 005-0405-mon_ROI_094_mask.tiff
# Processed file: 008-7473-mon_ROI_001_mask.tiff
# Processed file: 009-3193-mon_ROI_212_mask.tiff
# Processed file: 010-1208-mon_ROI_068_mask.tiff
# Processed file: 007-0845-mon_ROI_023_mask.tiff
# Processed file: 007-0295-mon_ROI_012_mask.tiff
# Processed file: 009-3247-mon_ROI_023_mask.tiff
# Processed file: 010-0073-mon_ROI_253_mask.tiff
# Processed file: 008-3453-mon_ROI_012_mask.tiff
# Processed file: 008-3207-mon_ROI_072_mask.tiff
# Processed file: 009-3196-mon_ROI_411_mask.tiff
# Processed file: 008-3346-mon_ROI_021_mask.tiff
# Processed file: 009-3347-mon_ROI_074_mask.tiff
# Processed file: 009-3202-mon_ROI_094_mask.tiff
# Processed file: 008-3230-mon_ROI_020_mask.tiff
# Processed file: 009-3193-mon_ROI_377_mask.tiff
# Processed file: 009-9703-mon_ROI_089_mask.tiff
# Processed file: 009-3220-mon_ROI_515_mask.tiff
# Processed file: 009-3220-mon_ROI_474_mask.tiff
# Processed file: 008-2940-mon_ROI_028_mask.tiff
# Processed file: 009-3398-mon_ROI_012_mask.tiff
# Processed file: 005-1035-mon_ROI_056_mask.tiff
# Processed file: 009-3193-mon_ROI_015_mask.tiff
# Processed file: 010-0073-mon_ROI_443_mask.tiff
# Processed file: 010-0073-mon_ROI_742_mask.tiff
# Processed file: 009-3202-mon_ROI_677_mask.tiff
# Processed file: 010-0790-mon_ROI_333_mask.tiff
# Processed file: 008-7524-mon_ROI_049_mask.tiff
# Processed file: 007-0084-mon_ROI_058_mask.tiff
# Processed file: 009-3196-mon_ROI_204_mask.tiff
# Processed file: 008-7481-mon_ROI_041_mask.tiff
# Processed file: 009-9703-mon_ROI_655_mask.tiff
# Processed file: 009-3347-mon_ROI_033_mask.tiff
# Processed file: 009-3196-mon_ROI_405_mask.tiff
# Processed file: 009-3410-mon_ROI_037_mask.tiff
# Processed file: 008-3230-mon_ROI_056_mask.tiff
# Processed file: 010-0073-mon_ROI_844_mask.tiff
# Processed file: 009-3202-mon_ROI_650_mask.tiff
# Processed file: 010-1208-mon_ROI_029_mask.tiff
# Processed file: 007-0258-mon_ROI_031_mask.tiff
# Processed file: 005-0447-mon_ROI_072_mask.tiff
# Processed file: 005-0309-mon_ROI_081_mask.tiff
# Processed file: 010-0073-mon_ROI_168_mask.tiff
# Processed file: 005-0854-mon_ROI_008_mask.tiff
# Processed file: 010-0119-mon_ROI_454_mask.tiff
# Processed file: 009-3196-mon_ROI_175_mask.tiff
# Processed file: 005-0250-mon_ROI_193_mask.tiff
# Processed file: 009-3410-mon_ROI_042_mask.tiff
# Processed file: 009-9703-mon_ROI_711_mask.tiff
# Processed file: 009-3220-mon_ROI_313_mask.tiff
# Processed file: 008-2935-mon_ROI_026_mask.tiff
# Processed file: 005-0361-mon_ROI_008_mask.tiff
# Processed file: 008-3332-mon_ROI_010_mask.tiff
# Processed file: 009-3202-mon_ROI_600_mask.tiff
# Processed file: 009-3196-mon_ROI_093_mask.tiff
# Processed file: 008-2913-mon_ROI_015_mask.tiff
# Processed file: 005-0576-mon_ROI_009_mask.tiff
# Processed file: 009-9703-mon_ROI_623_mask.tiff
# Processed file: 009-9703-mon_ROI_639_mask.tiff
# Processed file: 010-0999-mon_ROI_009_mask.tiff
# Processed file: 007-0173-mon_ROI_055_mask.tiff
# Processed file: 010-1239-mon_ROI_047_mask.tiff
# Processed file: 010-0790-mon_ROI_771_mask.tiff
# Processed file: 009-3266-mon_ROI_158_mask.tiff
# Processed file: 010-0790-mon_ROI_041_mask.tiff
# Processed file: 008-3340-mon_ROI_004_mask.tiff
# Processed file: 005-0447-mon_ROI_024_mask.tiff
# Processed file: 009-3220-mon_ROI_261_mask.tiff
# Processed file: 010-0119-mon_ROI_218_mask.tiff
# Processed file: 005-0250-mon_ROI_211_mask.tiff
# Processed file: 010-0790-mon_ROI_480_mask.tiff
# Processed file: 009-3220-mon_ROI_031_mask.tiff
# Processed file: 005-0576-mon_ROI_088_mask.tiff
# Processed file: 009-9752-mon_ROI_062_mask.tiff
# Processed file: 005-0309-mon_ROI_090_mask.tiff
# Processed file: 010-0790-mon_ROI_736_mask.tiff
# Processed file: 009-9703-mon_ROI_708_mask.tiff
# Processed file: 009-3220-mon_ROI_009_mask.tiff
# Processed file: 009-3196-mon_ROI_464_mask.tiff
# Processed file: 010-0119-mon_ROI_203_mask.tiff
# Processed file: 005-0886-mon_ROI_064_mask.tiff
# Processed file: 010-0119-mon_ROI_428_mask.tiff
# Processed file: 010-1424-mon_ROI_029_mask.tiff
# Processed file: 009-9703-mon_ROI_576_mask.tiff
# Processed file: 005-0250-mon_ROI_020_mask.tiff
# Processed file: 010-0119-mon_ROI_063_mask.tiff
# Processed file: 009-3229-mon_ROI_004_mask.tiff
# Processed file: 009-3193-mon_ROI_441_mask.tiff
# Processed file: 009-3196-mon_ROI_355_mask.tiff
# Processed file: 005-0836-mon_ROI_052_mask.tiff
# Processed file: 009-9703-mon_ROI_113_mask.tiff
# Processed file: 009-9654-mon_ROI_081_mask.tiff
# Processed file: 009-3220-mon_ROI_372_mask.tiff
# Processed file: 005-0250-mon_ROI_134_mask.tiff
# Processed file: 010-1239-mon_ROI_001_mask.tiff
# Processed file: 008-7473-mon_ROI_024_mask.tiff
# Processed file: 010-0790-mon_ROI_231_mask.tiff
# Processed file: 007-0137-mon_ROI_072_mask.tiff
# Processed file: 010-0119-mon_ROI_068_mask.tiff
# Processed file: 008-7681-mon_ROI_011_mask.tiff
# Processed file: 010-0790-mon_ROI_429_mask.tiff
# Processed file: 010-1208-mon_ROI_019_mask.tiff
# Processed file: 010-0119-mon_ROI_303_mask.tiff
# Processed file: 010-0073-mon_ROI_226_mask.tiff
# Processed file: 010-0505-mon_ROI_029_mask.tiff
# Processed file: 010-0073-mon_ROI_491_mask.tiff
# Processed file: 009-3202-mon_ROI_405_mask.tiff
# Processed file: 009-3337-mon_ROI_097_mask.tiff
# Processed file: 009-9703-mon_ROI_278_mask.tiff
# Processed file: 010-0073-mon_ROI_229_mask.tiff
# Processed file: 008-7515-mon_ROI_008_mask.tiff
# Processed file: 008-2980-mon_ROI_006_mask.tiff
# Processed file: 009-3410-mon_ROI_006_mask.tiff
# Processed file: 010-0073-mon_ROI_308_mask.tiff
# Processed file: 009-9703-mon_ROI_244_mask.tiff
# Processed file: 005-0854-mon_ROI_050_mask.tiff
# Processed file: 010-0073-mon_ROI_146_mask.tiff
# Processed file: 010-0073-mon_ROI_566_mask.tiff
# Processed file: 010-0790-mon_ROI_081_mask.tiff
# Processed file: 010-0073-mon_ROI_212_mask.tiff
# Processed file: 008-2913-mon_ROI_012_mask.tiff
# Processed file: 010-0073-mon_ROI_329_mask.tiff
# Processed file: 007-0211-mon_ROI_013_mask.tiff
# Processed file: 009-3202-mon_ROI_186_mask.tiff
# Processed file: 009-9703-mon_ROI_482_mask.tiff
# Processed file: 010-0505-mon_ROI_367_mask.tiff
# Processed file: 008-3088-mon_ROI_022_mask.tiff
# Processed file: 009-3229-mon_ROI_100_mask.tiff
# Processed file: 009-9703-mon_ROI_524_mask.tiff
# Processed file: 009-9703-mon_ROI_206_mask.tiff
# Processed file: 009-3202-mon_ROI_401_mask.tiff
# Processed file: 008-7429-mon_ROI_009_mask.tiff
# Processed file: 009-3193-mon_ROI_009_mask.tiff
# Processed file: 009-9703-mon_ROI_409_mask.tiff
# Processed file: 009-3196-mon_ROI_011_mask.tiff
# Processed file: 010-0505-mon_ROI_079_mask.tiff
# Processed file: 008-3038-mon_ROI_012_mask.tiff
# Processed file: 009-9703-mon_ROI_331_mask.tiff
# Processed file: 009-3532-mon_ROI_018_mask.tiff
# Processed file: 005-0250-mon_ROI_271_mask.tiff
# Processed file: 008-3230-mon_ROI_016_mask.tiff
# Processed file: 009-3229-mon_ROI_109_mask.tiff
# Processed file: 010-1461-mon_ROI_060_mask.tiff
# Processed file: 009-9703-mon_ROI_549_mask.tiff
# Processed file: 009-3202-mon_ROI_021_mask.tiff
# Processed file: 009-9703-mon_ROI_502_mask.tiff
# Processed file: 010-0505-mon_ROI_339_mask.tiff
# Processed file: 007-0178-mon_ROI_023_mask.tiff
# Processed file: 009-3266-mon_ROI_178_mask.tiff
# Processed file: 009-3193-mon_ROI_135_mask.tiff
# Processed file: 005-0886-mon_ROI_021_mask.tiff
# Processed file: 008-2972-mon_ROI_066_mask.tiff
# Processed file: 010-0119-mon_ROI_237_mask.tiff
# Processed file: 005-0309-mon_ROI_095_mask.tiff
# Processed file: 009-3406-mon_ROI_014_mask.tiff
# Processed file: 009-3220-mon_ROI_018_mask.tiff
# Processed file: 005-0250-mon_ROI_062_mask.tiff
# Processed file: 009-9703-mon_ROI_196_mask.tiff
# Processed file: 009-3343-mon_ROI_034_mask.tiff
# Processed file: 008-3212-mon_ROI_029_mask.tiff
# Processed file: 010-0073-mon_ROI_975_mask.tiff
# Processed file: 009-3220-mon_ROI_306_mask.tiff
# Processed file: 005-0447-mon_ROI_097_mask.tiff
# Processed file: 009-9752-mon_ROI_114_mask.tiff
# Processed file: 010-1008-mon_ROI_032_mask.tiff
# Processed file: 009-3193-mon_ROI_211_mask.tiff
# Processed file: 010-0119-mon_ROI_533_mask.tiff
# Processed file: 009-3196-mon_ROI_543_mask.tiff
# Processed file: 009-9703-mon_ROI_680_mask.tiff
# Processed file: 008-3453-mon_ROI_044_mask.tiff
# Processed file: 010-0119-mon_ROI_441_mask.tiff
# Processed file: 009-9654-mon_ROI_055_mask.tiff
# Processed file: 010-0947-mon_ROI_030_mask.tiff
# Processed file: 009-3247-mon_ROI_087_mask.tiff
# Processed file: 010-1424-mon_ROI_020_mask.tiff
# Processed file: 009-3202-mon_ROI_594_mask.tiff
# Processed file: 005-0250-mon_ROI_008_mask.tiff
# Processed file: 009-3193-mon_ROI_263_mask.tiff
# Processed file: 010-0790-mon_ROI_399_mask.tiff
# Processed file: 009-9752-mon_ROI_325_mask.tiff
# Processed file: 010-0790-mon_ROI_008_mask.tiff
# Processed file: 010-0119-mon_ROI_601_mask.tiff
# Processed file: 010-1461-mon_ROI_021_mask.tiff
# Processed file: 010-0073-mon_ROI_394_mask.tiff
# Processed file: 010-0790-mon_ROI_370_mask.tiff
# Processed file: 010-0790-mon_ROI_037_mask.tiff
# Processed file: 010-0505-mon_ROI_070_mask.tiff
# Processed file: 009-9703-mon_ROI_684_mask.tiff
# Processed file: 009-9703-mon_ROI_483_mask.tiff
# Processed file: 009-3266-mon_ROI_078_mask.tiff
# Processed file: 009-3337-mon_ROI_027_mask.tiff
# Processed file: 010-0073-mon_ROI_037_mask.tiff
# Processed file: 009-9654-mon_ROI_035_mask.tiff
# Processed file: 010-0073-mon_ROI_747_mask.tiff
# Processed file: 008-2972-mon_ROI_061_mask.tiff
# Processed file: 010-0119-mon_ROI_053_mask.tiff
# Processed file: 007-0258-mon_ROI_016_mask.tiff
# Processed file: 005-0447-mon_ROI_055_mask.tiff
# Processed file: 008-7681-mon_ROI_022_mask.tiff
# Processed file: 010-1239-mon_ROI_069_mask.tiff
# Processed file: 010-0790-mon_ROI_374_mask.tiff
# Processed file: 010-0073-mon_ROI_289_mask.tiff
# Processed file: 010-0790-mon_ROI_219_mask.tiff
# Processed file: 009-9752-mon_ROI_273_mask.tiff
# Processed file: 009-3193-mon_ROI_312_mask.tiff
# Processed file: 010-0073-mon_ROI_773_mask.tiff
# Processed file: 009-3202-mon_ROI_526_mask.tiff
# Processed file: 009-3196-mon_ROI_377_mask.tiff
# Processed file: 009-3196-mon_ROI_399_mask.tiff
# Processed file: 010-0073-mon_ROI_142_mask.tiff
# Processed file: 008-3346-mon_ROI_000_mask.tiff
# Processed file: 009-3202-mon_ROI_076_mask.tiff
# Processed file: 010-0790-mon_ROI_633_mask.tiff
# Processed file: 005-0447-mon_ROI_015_mask.tiff
# Processed file: 005-0354-mon_ROI_074_mask.tiff
# Processed file: 009-3196-mon_ROI_288_mask.tiff
# Processed file: 005-0250-mon_ROI_124_mask.tiff
# Processed file: 009-3202-mon_ROI_367_mask.tiff
# Processed file: 010-1208-mon_ROI_018_mask.tiff
# Processed file: 009-3295-mon_ROI_121_mask.tiff
# Processed file: 009-3266-mon_ROI_033_mask.tiff
# Processed file: 009-3202-mon_ROI_183_mask.tiff
# Processed file: 010-1461-mon_ROI_052_mask.tiff
# Processed file: 009-3347-mon_ROI_067_mask.tiff
# Processed file: 010-0505-mon_ROI_240_mask.tiff
# Processed file: 010-1471-mon_ROI_046_mask.tiff
# Processed file: 010-0790-mon_ROI_527_mask.tiff
# Processed file: 007-0211-mon_ROI_008_mask.tiff
# Processed file: 010-1461-mon_ROI_025_mask.tiff
# Processed file: 008-7481-mon_ROI_023_mask.tiff
# Processed file: 010-0896-mon_ROI_019_mask.tiff
# Processed file: 009-3193-mon_ROI_271_mask.tiff
# Processed file: 007-0295-mon_ROI_027_mask.tiff
# Processed file: 010-0073-mon_ROI_867_mask.tiff
# Processed file: 008-3456-mon_ROI_001_mask.tiff
# Processed file: 009-3247-mon_ROI_014_mask.tiff
# Processed file: 010-1239-mon_ROI_043_mask.tiff
# Processed file: 010-0119-mon_ROI_278_mask.tiff
# Processed file: 007-0408-mon_ROI_044_mask.tiff
# Processed file: 009-3220-mon_ROI_255_mask.tiff
# Processed file: 007-0173-mon_ROI_046_mask.tiff
# Processed file: 009-3220-mon_ROI_394_mask.tiff
# Processed file: 010-0119-mon_ROI_636_mask.tiff
# Processed file: 009-3193-mon_ROI_347_mask.tiff
# Processed file: 010-0790-mon_ROI_144_mask.tiff
# Processed file: 008-2980-mon_ROI_042_mask.tiff
# Processed file: 009-3196-mon_ROI_386_mask.tiff
# Processed file: 007-0408-mon_ROI_040_mask.tiff
# Processed file: 005-0447-mon_ROI_130_mask.tiff
# Processed file: 009-3202-mon_ROI_433_mask.tiff
# Processed file: 005-1062-mon_ROI_009_mask.tiff
# Processed file: 008-7564-mon_ROI_022_mask.tiff
# Processed file: 010-0790-mon_ROI_716_mask.tiff
# Processed file: 008-3453-mon_ROI_028_mask.tiff
# Processed file: 010-1208-mon_ROI_030_mask.tiff
# Processed file: 009-3196-mon_ROI_232_mask.tiff
# Processed file: 009-3202-mon_ROI_080_mask.tiff
# Processed file: 010-0505-mon_ROI_409_mask.tiff
# Processed file: 009-3266-mon_ROI_124_mask.tiff
# Processed file: 010-0790-mon_ROI_701_mask.tiff
# Processed file: 010-0896-mon_ROI_089_mask.tiff
# Processed file: 009-3193-mon_ROI_230_mask.tiff
# Processed file: 009-3266-mon_ROI_013_mask.tiff
# Processed file: 005-0361-mon_ROI_022_mask.tiff
# Processed file: 008-7564-mon_ROI_005_mask.tiff
# Processed file: 009-9654-mon_ROI_006_mask.tiff
# Processed file: 009-3347-mon_ROI_012_mask.tiff
# Processed file: 010-0073-mon_ROI_039_mask.tiff
# Processed file: 009-3193-mon_ROI_466_mask.tiff
# Processed file: 010-0119-mon_ROI_220_mask.tiff
# Processed file: 010-0119-mon_ROI_395_mask.tiff
# Processed file: 005-0309-mon_ROI_053_mask.tiff
# Processed file: 005-1215-mon_ROI_036_mask.tiff
# Processed file: 009-3196-mon_ROI_585_mask.tiff
# Processed file: 009-3524-mon_ROI_006_mask.tiff
# Processed file: 009-9703-mon_ROI_628_mask.tiff
# Processed file: 009-3196-mon_ROI_504_mask.tiff
# Processed file: 008-7755-mon_ROI_002_mask.tiff
# Processed file: 010-1199-mon_ROI_018_mask.tiff
# Processed file: 009-3196-mon_ROI_558_mask.tiff
# Processed file: 010-0073-mon_ROI_967_mask.tiff
# Processed file: 009-9752-mon_ROI_226_mask.tiff
# Processed file: 009-3193-mon_ROI_264_mask.tiff
# Processed file: 008-3340-mon_ROI_032_mask.tiff
# Processed file: 009-3347-mon_ROI_020_mask.tiff
# Processed file: 009-3266-mon_ROI_021_mask.tiff
# Processed file: 010-0790-mon_ROI_754_mask.tiff
# Processed file: 010-0505-mon_ROI_353_mask.tiff
# Processed file: 008-7429-mon_ROI_013_mask.tiff
# Processed file: 008-3346-mon_ROI_012_mask.tiff
# Processed file: 005-0836-mon_ROI_041_mask.tiff
# Processed file: 009-3202-mon_ROI_592_mask.tiff
# Processed file: 010-1461-mon_ROI_067_mask.tiff
# Processed file: 009-3347-mon_ROI_023_mask.tiff
# Processed file: 010-0073-mon_ROI_189_mask.tiff
# Processed file: 005-1035-mon_ROI_052_mask.tiff
# Processed file: 005-1035-mon_ROI_059_mask.tiff
# Processed file: 009-3220-mon_ROI_066_mask.tiff
# Processed file: 008-3230-mon_ROI_009_mask.tiff
# Processed file: 005-0707-mon_ROI_062_mask.tiff
# Processed file: 009-3337-mon_ROI_095_mask.tiff
# Processed file: 008-3453-mon_ROI_033_mask.tiff
# Processed file: 009-3193-mon_ROI_429_mask.tiff
# Processed file: 010-0505-mon_ROI_356_mask.tiff
# Processed file: 007-1042-mon_ROI_012_mask.tiff
# Processed file: 008-7755-mon_ROI_011_mask.tiff
# Processed file: 008-7684-mon_ROI_006_mask.tiff
# Processed file: 008-7476-mon_ROI_002_mask.tiff
# Processed file: 009-9654-mon_ROI_028_mask.tiff
# Processed file: 007-0408-mon_ROI_020_mask.tiff
# Processed file: 005-1071-mon_ROI_012_mask.tiff
# Processed file: 009-3220-mon_ROI_279_mask.tiff
# Processed file: 007-0326-mon_ROI_038_mask.tiff
# Processed file: 010-0505-mon_ROI_101_mask.tiff
# Processed file: 009-3193-mon_ROI_059_mask.tiff
# Processed file: 009-3202-mon_ROI_375_mask.tiff
# Processed file: 009-3202-mon_ROI_125_mask.tiff
# Processed file: 010-0790-mon_ROI_434_mask.tiff
# Processed file: 009-3266-mon_ROI_140_mask.tiff
# Processed file: 009-3247-mon_ROI_060_mask.tiff
# Processed file: 009-9703-mon_ROI_380_mask.tiff
# Processed file: 010-0119-mon_ROI_501_mask.tiff
# Processed file: 007-0084-mon_ROI_029_mask.tiff
# Processed file: 005-0447-mon_ROI_116_mask.tiff
# Processed file: 010-0119-mon_ROI_518_mask.tiff
# Processed file: 009-9703-mon_ROI_575_mask.tiff
# Processed file: 007-0360-mon_ROI_027_mask.tiff
# Processed file: 005-0854-mon_ROI_094_mask.tiff
# Processed file: 009-9703-mon_ROI_297_mask.tiff
# Processed file: 005-1062-mon_ROI_000_mask.tiff
# Processed file: 005-0854-mon_ROI_023_mask.tiff
# Processed file: 009-9654-mon_ROI_008_mask.tiff
# Processed file: 009-3202-mon_ROI_089_mask.tiff
# Processed file: 010-0896-mon_ROI_044_mask.tiff
# Processed file: 009-9703-mon_ROI_762_mask.tiff
# Processed file: 010-0119-mon_ROI_134_mask.tiff
# Processed file: 009-3196-mon_ROI_030_mask.tiff
# Processed file: 009-9752-mon_ROI_083_mask.tiff
# Processed file: 009-9703-mon_ROI_534_mask.tiff
# Processed file: 010-1008-mon_ROI_051_mask.tiff
# Processed file: 005-1215-mon_ROI_019_mask.tiff
# Processed file: 010-0119-mon_ROI_362_mask.tiff
# Processed file: 009-9752-mon_ROI_150_mask.tiff
# Processed file: 010-0119-mon_ROI_234_mask.tiff
# Processed file: 009-3220-mon_ROI_330_mask.tiff
# Processed file: 008-3466-mon_ROI_014_mask.tiff
# Processed file: 010-0073-mon_ROI_067_mask.tiff
# Processed file: 010-0896-mon_ROI_110_mask.tiff
# Processed file: 005-0804-mon_ROI_035_mask.tiff
# Processed file: 009-3295-mon_ROI_103_mask.tiff
# Processed file: 008-3038-mon_ROI_017_mask.tiff
# Processed file: 009-3202-mon_ROI_346_mask.tiff
# Processed file: 009-3193-mon_ROI_277_mask.tiff
# Processed file: 010-0073-mon_ROI_786_mask.tiff
# Processed file: 007-0137-mon_ROI_013_mask.tiff
# Processed file: 009-3220-mon_ROI_005_mask.tiff
# Processed file: 007-0178-mon_ROI_002_mask.tiff
# Processed file: 010-1239-mon_ROI_075_mask.tiff
# Processed file: 010-0119-mon_ROI_483_mask.tiff
# Processed file: 009-3202-mon_ROI_465_mask.tiff
# Processed file: 010-0790-mon_ROI_112_mask.tiff
# Processed file: 009-9703-mon_ROI_746_mask.tiff
# Processed file: 009-9703-mon_ROI_562_mask.tiff
# Processed file: 009-9703-mon_ROI_734_mask.tiff
# Processed file: 005-0309-mon_ROI_110_mask.tiff
# Processed file: 010-0896-mon_ROI_046_mask.tiff
# Processed file: 009-3193-mon_ROI_000_mask.tiff
# Processed file: 009-3196-mon_ROI_193_mask.tiff
# Processed file: 010-0790-mon_ROI_158_mask.tiff
# Processed file: 010-0119-mon_ROI_465_mask.tiff
# Processed file: 005-0354-mon_ROI_047_mask.tiff
# Processed file: 010-1199-mon_ROI_016_mask.tiff
# Processed file: 009-3229-mon_ROI_073_mask.tiff
# Processed file: 009-3229-mon_ROI_128_mask.tiff
# Processed file: 005-0309-mon_ROI_094_mask.tiff
# Processed file: 005-0250-mon_ROI_160_mask.tiff
# Processed file: 010-0073-mon_ROI_562_mask.tiff
# Processed file: 005-0836-mon_ROI_029_mask.tiff
# Processed file: 009-3220-mon_ROI_383_mask.tiff
# Processed file: 009-3193-mon_ROI_316_mask.tiff
# Processed file: 010-0073-mon_ROI_406_mask.tiff
# Processed file: 010-0073-mon_ROI_613_mask.tiff
# Processed file: 010-1239-mon_ROI_060_mask.tiff
# Processed file: 009-3193-mon_ROI_436_mask.tiff
# Processed file: 005-0576-mon_ROI_086_mask.tiff
# Processed file: 010-0790-mon_ROI_603_mask.tiff
# Processed file: 009-3266-mon_ROI_009_mask.tiff
# Processed file: 005-0354-mon_ROI_025_mask.tiff
# Processed file: 009-3202-mon_ROI_508_mask.tiff
# Processed file: 010-0073-mon_ROI_128_mask.tiff
# Processed file: 009-3196-mon_ROI_460_mask.tiff
# Processed file: 009-3196-mon_ROI_210_mask.tiff
# Processed file: 010-0073-mon_ROI_413_mask.tiff
# Processed file: 010-0119-mon_ROI_435_mask.tiff
# Processed file: 010-0790-mon_ROI_160_mask.tiff
# Processed file: 010-0119-mon_ROI_263_mask.tiff
# Processed file: 008-7473-mon_ROI_038_mask.tiff
# Processed file: 009-3247-mon_ROI_000_mask.tiff
# Processed file: 009-9703-mon_ROI_681_mask.tiff
# Processed file: 009-3220-mon_ROI_337_mask.tiff
# Processed file: 009-3220-mon_ROI_089_mask.tiff
# Processed file: 010-0896-mon_ROI_086_mask.tiff
# Processed file: 010-0119-mon_ROI_511_mask.tiff
# Processed file: 009-9752-mon_ROI_005_mask.tiff
# Processed file: 008-7473-mon_ROI_047_mask.tiff
# Processed file: 009-3193-mon_ROI_113_mask.tiff
# Processed file: 005-0405-mon_ROI_003_mask.tiff
# Processed file: 005-0354-mon_ROI_022_mask.tiff
# Processed file: 010-0790-mon_ROI_421_mask.tiff
# Processed file: 009-3295-mon_ROI_120_mask.tiff
# Processed file: 010-0073-mon_ROI_840_mask.tiff
# Processed file: 005-0405-mon_ROI_022_mask.tiff
# Processed file: 008-3212-mon_ROI_032_mask.tiff
# Processed file: 010-0073-mon_ROI_020_mask.tiff
# Processed file: 008-3453-mon_ROI_022_mask.tiff
# Processed file: 009-9752-mon_ROI_104_mask.tiff
# Processed file: 005-0804-mon_ROI_025_mask.tiff
# Processed file: 010-1008-mon_ROI_044_mask.tiff
# Processed file: 008-3094-mon_ROI_048_mask.tiff
# Processed file: 010-0119-mon_ROI_387_mask.tiff
# Processed file: 010-0073-mon_ROI_946_mask.tiff
# Processed file: 008-7425-mon_ROI_029_mask.tiff
# Processed file: 009-3347-mon_ROI_071_mask.tiff
# Processed file: 005-1062-mon_ROI_014_mask.tiff
# Processed file: 009-3337-mon_ROI_041_mask.tiff
# Processed file: 010-0073-mon_ROI_707_mask.tiff
# Processed file: 008-7564-mon_ROI_035_mask.tiff
# Processed file: 008-7763-mon_ROI_002_mask.tiff
# Processed file: 009-3247-mon_ROI_122_mask.tiff
# Processed file: 009-9703-mon_ROI_138_mask.tiff
# Processed file: 009-3266-mon_ROI_142_mask.tiff
# Processed file: 007-0408-mon_ROI_049_mask.tiff
# Processed file: 007-0137-mon_ROI_048_mask.tiff
# Processed file: 009-3304-mon_ROI_054_mask.tiff
# Processed file: 005-0886-mon_ROI_093_mask.tiff
# Processed file: 008-3148-mon_ROI_007_mask.tiff
# Processed file: 009-3266-mon_ROI_050_mask.tiff
# Processed file: 008-3212-mon_ROI_010_mask.tiff
# Processed file: 009-9752-mon_ROI_078_mask.tiff
# Processed file: 010-0073-mon_ROI_155_mask.tiff
# Processed file: 005-1071-mon_ROI_002_mask.tiff
# Processed file: 007-0084-mon_ROI_028_mask.tiff
# Processed file: 009-3202-mon_ROI_641_mask.tiff
# Processed file: 008-2980-mon_ROI_040_mask.tiff
# Processed file: 005-0250-mon_ROI_038_mask.tiff
# Processed file: 010-1008-mon_ROI_015_mask.tiff
# Processed file: 010-0505-mon_ROI_332_mask.tiff
# Processed file: 008-7515-mon_ROI_011_mask.tiff
# Processed file: 009-3193-mon_ROI_352_mask.tiff
# Processed file: 009-3527-mon_ROI_011_mask.tiff
# Processed file: 009-9703-mon_ROI_673_mask.tiff
# Processed file: 009-3266-mon_ROI_225_mask.tiff
# Processed file: 010-0073-mon_ROI_749_mask.tiff
# Processed file: 009-3295-mon_ROI_027_mask.tiff
# Processed file: 009-3193-mon_ROI_123_mask.tiff
# Processed file: 005-0405-mon_ROI_002_mask.tiff
# Processed file: 009-9703-mon_ROI_740_mask.tiff
# Processed file: 010-1053-mon_ROI_006_mask.tiff
# Processed file: 010-0073-mon_ROI_234_mask.tiff
# Processed file: 005-1071-mon_ROI_061_mask.tiff
# Processed file: 009-3247-mon_ROI_045_mask.tiff
# Processed file: 009-3202-mon_ROI_036_mask.tiff
# Processed file: 009-3196-mon_ROI_118_mask.tiff
# Processed file: 010-0505-mon_ROI_019_mask.tiff
# Processed file: 007-0211-mon_ROI_059_mask.tiff
# Processed file: 009-3295-mon_ROI_093_mask.tiff
# Processed file: 009-9752-mon_ROI_011_mask.tiff
# Processed file: 009-3266-mon_ROI_209_mask.tiff
# Processed file: 010-0119-mon_ROI_390_mask.tiff
# Processed file: 010-0073-mon_ROI_330_mask.tiff
# Processed file: 007-0211-mon_ROI_007_mask.tiff
# Processed file: 005-1035-mon_ROI_051_mask.tiff
# Processed file: 009-3266-mon_ROI_149_mask.tiff
# Processed file: 005-0405-mon_ROI_011_mask.tiff
# Processed file: 010-0119-mon_ROI_038_mask.tiff
# Processed file: 010-0790-mon_ROI_485_mask.tiff
# Processed file: 009-3247-mon_ROI_008_mask.tiff
# Processed file: 009-3247-mon_ROI_064_mask.tiff
# Processed file: 009-3202-mon_ROI_655_mask.tiff
# Processed file: 010-1461-mon_ROI_042_mask.tiff
# Processed file: 008-3230-mon_ROI_011_mask.tiff
# Processed file: 008-7681-mon_ROI_020_mask.tiff
# Processed file: 009-9703-mon_ROI_274_mask.tiff
# Processed file: 005-0354-mon_ROI_096_mask.tiff
# Processed file: 009-3220-mon_ROI_192_mask.tiff
# Processed file: 009-3202-mon_ROI_135_mask.tiff
# Processed file: 010-0505-mon_ROI_320_mask.tiff
# ...
# Processed file: 010-0896-mon_ROI_119_mask.tiff
# Processed file: 009-9654-mon_ROI_109_mask.tiff
# Processed file: 009-3220-mon_ROI_179_mask.tiff
# Processed file: 010-1239-mon_ROI_041_mask.tiff
# Processed file: 009-3196-mon_ROI_192_mask.tiff
# Processed file: 008-7524-mon_ROI_054_mask.tiff
# Processed file: 009-9752-mon_ROI_288_mask.tiff
# Processed file: 005-0309-mon_ROI_009_mask.tiff
# Processed file: 007-0173-mon_ROI_012_mask.tiff
# Processed file: 010-1199-mon_ROI_007_mask.tiff
# Processed file: 009-3196-mon_ROI_573_mask.tiff
# Processed file: 008-2935-mon_ROI_000_mask.tiff
# Processed file: 009-3229-mon_ROI_018_mask.tiff
# Processed file: 009-3202-mon_ROI_130_mask.tiff
# Processed file: 009-3220-mon_ROI_253_mask.tiff
# Processed file: 008-3453-mon_ROI_046_mask.tiff
# Processed file: 009-9703-mon_ROI_446_mask.tiff
# Processed file: 009-3220-mon_ROI_373_mask.tiff
# Processed file: 010-0073-mon_ROI_625_mask.tiff
# Processed file: 010-0119-mon_ROI_430_mask.tiff
# Processed file: 005-0854-mon_ROI_031_mask.tiff
# Processed file: 008-3332-mon_ROI_011_mask.tiff
# Processed file: 005-0886-mon_ROI_002_mask.tiff
# Processed file: 009-9752-mon_ROI_161_mask.tiff
# Processed file: 005-0854-mon_ROI_046_mask.tiff
# Processed file: 009-9654-mon_ROI_011_mask.tiff
# Processed file: 009-9703-mon_ROI_161_mask.tiff
# Processed file: 005-1071-mon_ROI_053_mask.tiff
# Processed file: 009-3196-mon_ROI_494_mask.tiff
# Processed file: 009-3202-mon_ROI_086_mask.tiff
# Processed file: 010-0505-mon_ROI_004_mask.tiff
# Processed file: 010-0790-mon_ROI_031_mask.tiff
# Processed file: 005-0250-mon_ROI_041_mask.tiff
# Processed file: 009-3220-mon_ROI_258_mask.tiff
# Processed file: 010-0119-mon_ROI_527_mask.tiff
# Processed file: 009-3193-mon_ROI_367_mask.tiff
# Processed file: 010-0073-mon_ROI_445_mask.tiff
# Processed file: 007-0326-mon_ROI_047_mask.tiff
# Processed file: 009-3193-mon_ROI_379_mask.tiff
# Processed file: 009-9703-mon_ROI_755_mask.tiff
# Processed file: 010-0073-mon_ROI_806_mask.tiff
# Processed file: 009-3202-mon_ROI_074_mask.tiff
# Processed file: 005-1215-mon_ROI_018_mask.tiff
# Processed file: 007-0137-mon_ROI_076_mask.tiff
# Processed file: 009-9703-mon_ROI_386_mask.tiff
# Processed file: 008-2913-mon_ROI_004_mask.tiff
# Processed file: 008-7425-mon_ROI_024_mask.tiff
# Processed file: 009-9752-mon_ROI_149_mask.tiff
# Processed file: 010-0790-mon_ROI_742_mask.tiff
# Processed file: 009-3193-mon_ROI_133_mask.tiff
# Processed file: 009-3343-mon_ROI_000_mask.tiff
# Processed file: 009-9752-mon_ROI_058_mask.tiff
# Processed file: 007-0178-mon_ROI_015_mask.tiff
# Processed file: 010-0505-mon_ROI_044_mask.tiff
# Processed file: 009-9703-mon_ROI_195_mask.tiff
# Processed file: 005-0250-mon_ROI_125_mask.tiff
# Processed file: 009-3347-mon_ROI_073_mask.tiff
# Processed file: 009-3202-mon_ROI_386_mask.tiff
# Processed file: 010-1208-mon_ROI_034_mask.tiff
# Processed file: 009-3202-mon_ROI_519_mask.tiff
# Processed file: 005-0354-mon_ROI_044_mask.tiff
# Processed file: 008-3148-mon_ROI_023_mask.tiff
# Processed file: 009-3266-mon_ROI_170_mask.tiff
# Processed file: 005-0804-mon_ROI_060_mask.tiff
# Processed file: 009-3343-mon_ROI_006_mask.tiff
# Processed file: 009-9703-mon_ROI_650_mask.tiff
# Processed file: 010-0790-mon_ROI_757_mask.tiff
# Processed file: 010-0119-mon_ROI_126_mask.tiff
# Processed file: 009-3196-mon_ROI_281_mask.tiff
# Processed file: 009-3196-mon_ROI_114_mask.tiff
# Processed file: 009-3247-mon_ROI_048_mask.tiff
# Processed file: 010-0790-mon_ROI_295_mask.tiff
# Processed file: 007-0137-mon_ROI_083_mask.tiff
# Processed file: 009-3193-mon_ROI_258_mask.tiff
# Processed file: 005-0886-mon_ROI_035_mask.tiff
# Processed file: 007-0211-mon_ROI_025_mask.tiff
# Processed file: 005-1071-mon_ROI_030_mask.tiff
# Processed file: 010-0505-mon_ROI_005_mask.tiff
# Processed file: 005-0250-mon_ROI_265_mask.tiff
# Processed file: 009-9654-mon_ROI_045_mask.tiff
# Processed file: 007-0326-mon_ROI_044_mask.tiff
# Processed file: 007-0287-mon_ROI_028_mask.tiff
# Processed file: 008-7519-mon_ROI_006_mask.tiff
# Processed file: 010-0505-mon_ROI_188_mask.tiff
# Processed file: 007-0295-mon_ROI_042_mask.tiff
# Processed file: 005-0405-mon_ROI_070_mask.tiff
# Processed file: 010-0073-mon_ROI_412_mask.tiff
# Processed file: 009-3337-mon_ROI_110_mask.tiff
# Processed file: 010-0073-mon_ROI_069_mask.tiff
# Processed file: 007-0876-mon_ROI_005_mask.tiff
# Processed file: 009-3295-mon_ROI_033_mask.tiff
# Processed file: 008-2972-mon_ROI_005_mask.tiff
# Processed file: 009-3410-mon_ROI_058_mask.tiff
# Processed file: 010-1239-mon_ROI_095_mask.tiff
# Processed file: 010-0119-mon_ROI_138_mask.tiff
# Processed file: 010-0999-mon_ROI_004_mask.tiff
# Processed file: 010-0073-mon_ROI_932_mask.tiff
# Processed file: 007-0178-mon_ROI_010_mask.tiff
# Processed file: 005-1035-mon_ROI_019_mask.tiff
# Processed file: 010-0119-mon_ROI_554_mask.tiff
# Processed file: 005-0250-mon_ROI_123_mask.tiff
# Processed file: 010-0947-mon_ROI_059_mask.tiff
# Processed file: 009-3220-mon_ROI_402_mask.tiff
# Processed file: 005-0447-mon_ROI_146_mask.tiff
# Processed file: 009-3202-mon_ROI_403_mask.tiff
# Processed file: 009-9752-mon_ROI_262_mask.tiff
# Processed file: 010-0505-mon_ROI_220_mask.tiff
# Processed file: 010-1208-mon_ROI_016_mask.tiff
# Processed file: 009-9752-mon_ROI_086_mask.tiff
# Processed file: 008-7425-mon_ROI_007_mask.tiff
# Processed file: 007-0408-mon_ROI_009_mask.tiff
# Processed file: 009-3202-mon_ROI_119_mask.tiff
# Processed file: 007-0137-mon_ROI_046_mask.tiff
# Processed file: 005-0250-mon_ROI_260_mask.tiff
# Processed file: 008-2940-mon_ROI_016_mask.tiff
# Processed file: 007-0326-mon_ROI_036_mask.tiff
# Processed file: 005-1035-mon_ROI_047_mask.tiff
# Processed file: 007-1031-mon_ROI_007_mask.tiff
# Processed file: 009-3202-mon_ROI_249_mask.tiff
# Processed file: 010-0790-mon_ROI_329_mask.tiff
# Processed file: 009-9703-mon_ROI_116_mask.tiff
# Processed file: 010-0896-mon_ROI_087_mask.tiff
# Processed file: 008-3148-mon_ROI_016_mask.tiff
# Processed file: 009-3304-mon_ROI_019_mask.tiff
# Processed file: 009-3229-mon_ROI_136_mask.tiff
# Processed file: 008-3230-mon_ROI_051_mask.tiff
# Processed file: 009-3202-mon_ROI_340_mask.tiff
# Processed file: 007-0295-mon_ROI_020_mask.tiff
# Processed file: 005-0250-mon_ROI_155_mask.tiff
# Processed file: 010-0896-mon_ROI_080_mask.tiff
# Processed file: 010-0999-mon_ROI_020_mask.tiff
# Processed file: 010-1239-mon_ROI_056_mask.tiff
# Processed file: 007-0360-mon_ROI_011_mask.tiff
# Processed file: 009-3196-mon_ROI_334_mask.tiff
# Processed file: 009-9703-mon_ROI_060_mask.tiff
# Processed file: 007-0173-mon_ROI_025_mask.tiff
# Processed file: 007-0876-mon_ROI_024_mask.tiff
# Processed file: 009-3229-mon_ROI_023_mask.tiff
# Processed file: 009-3202-mon_ROI_181_mask.tiff
# Processed file: 009-3220-mon_ROI_042_mask.tiff
# Processed file: 009-9703-mon_ROI_463_mask.tiff
# Processed file: 009-9752-mon_ROI_241_mask.tiff
# Processed file: 010-0119-mon_ROI_260_mask.tiff
# Processed file: 005-0447-mon_ROI_076_mask.tiff
# Processed file: 007-0137-mon_ROI_010_mask.tiff
# Processed file: 010-0790-mon_ROI_764_mask.tiff
# Processed file: 008-7573-mon_ROI_015_mask.tiff
# Processed file: 009-9703-mon_ROI_499_mask.tiff
# Processed file: 009-3527-mon_ROI_003_mask.tiff
# Processed file: 005-0405-mon_ROI_085_mask.tiff
# Processed file: 005-0886-mon_ROI_088_mask.tiff
# Processed file: 010-0790-mon_ROI_199_mask.tiff
# Processed file: 008-3340-mon_ROI_012_mask.tiff
# Processed file: 010-0073-mon_ROI_904_mask.tiff
# Processed file: 009-3202-mon_ROI_365_mask.tiff
# Processed file: 009-3202-mon_ROI_236_mask.tiff
# Processed file: 009-3337-mon_ROI_014_mask.tiff
# Processed file: 009-3196-mon_ROI_237_mask.tiff
# Processed file: 010-0119-mon_ROI_008_mask.tiff
# Processed file: 005-1215-mon_ROI_004_mask.tiff
# Processed file: 010-0073-mon_ROI_606_mask.tiff
# Processed file: 005-0707-mon_ROI_041_mask.tiff
# Processed file: 007-0528-mon_ROI_010_mask.tiff
# Processed file: 010-0505-mon_ROI_138_mask.tiff
# Processed file: 007-0258-mon_ROI_054_mask.tiff
# Processed file: 008-7689-mon_ROI_008_mask.tiff
# Processed file: 010-1239-mon_ROI_074_mask.tiff
# Processed file: 009-3410-mon_ROI_056_mask.tiff
# Processed file: 009-3202-mon_ROI_483_mask.tiff
# Processed file: 005-0309-mon_ROI_046_mask.tiff
# Processed file: 010-0505-mon_ROI_281_mask.tiff
# Processed file: 009-3220-mon_ROI_003_mask.tiff
# Processed file: 008-3453-mon_ROI_057_mask.tiff
# Processed file: 009-9703-mon_ROI_236_mask.tiff
# Processed file: 010-0505-mon_ROI_209_mask.tiff
# Processed file: 007-0258-mon_ROI_034_mask.tiff
# Processed file: 008-7425-mon_ROI_002_mask.tiff
# Processed file: 009-3193-mon_ROI_045_mask.tiff
# Processed file: 010-0947-mon_ROI_045_mask.tiff
# Processed file: 005-0250-mon_ROI_141_mask.tiff
# Processed file: 010-0790-mon_ROI_746_mask.tiff
# Processed file: 009-3406-mon_ROI_005_mask.tiff
# Processed file: 010-0505-mon_ROI_076_mask.tiff
# Processed file: 009-9703-mon_ROI_320_mask.tiff
# Processed file: 009-9703-mon_ROI_098_mask.tiff
# Processed file: 005-0576-mon_ROI_033_mask.tiff
# Processed file: 008-2913-mon_ROI_018_mask.tiff
# Processed file: 009-3196-mon_ROI_512_mask.tiff
# Processed file: 008-2913-mon_ROI_060_mask.tiff
# Processed file: 007-0360-mon_ROI_016_mask.tiff
# Processed file: 009-3304-mon_ROI_072_mask.tiff
# Processed file: 009-3202-mon_ROI_190_mask.tiff
# Processed file: 010-0119-mon_ROI_075_mask.tiff
# Processed file: 008-3466-mon_ROI_020_mask.tiff
# Processed file: 009-3193-mon_ROI_458_mask.tiff
# Processed file: 005-1035-mon_ROI_067_mask.tiff
# Processed file: 005-0354-mon_ROI_081_mask.tiff
# Processed file: 010-0073-mon_ROI_204_mask.tiff
# Processed file: 009-3398-mon_ROI_023_mask.tiff
# Processed file: 010-0505-mon_ROI_299_mask.tiff
# Processed file: 009-3202-mon_ROI_229_mask.tiff
# Processed file: 010-0790-mon_ROI_055_mask.tiff
# Processed file: 009-9654-mon_ROI_112_mask.tiff
# Processed file: 010-0073-mon_ROI_511_mask.tiff
# Processed file: 009-3304-mon_ROI_016_mask.tiff
# Processed file: 005-1215-mon_ROI_010_mask.tiff
# Processed file: 005-0854-mon_ROI_024_mask.tiff
# Processed file: 005-0804-mon_ROI_013_mask.tiff
# Processed file: 009-3220-mon_ROI_177_mask.tiff
# Processed file: 005-1035-mon_ROI_006_mask.tiff
# Processed file: 009-9703-mon_ROI_299_mask.tiff
# Processed file: 010-1008-mon_ROI_037_mask.tiff
# Processed file: 008-2935-mon_ROI_021_mask.tiff
# Processed file: 009-3202-mon_ROI_162_mask.tiff
# Processed file: 010-0073-mon_ROI_895_mask.tiff
# Processed file: 005-0250-mon_ROI_042_mask.tiff
# Processed file: 005-0854-mon_ROI_064_mask.tiff
# Processed file: 010-0505-mon_ROI_141_mask.tiff
# Processed file: 005-0250-mon_ROI_034_mask.tiff
# Processed file: 009-9703-mon_ROI_302_mask.tiff
# Processed file: 009-3202-mon_ROI_208_mask.tiff
# Processed file: 010-0790-mon_ROI_093_mask.tiff
# Processed file: 010-0947-mon_ROI_056_mask.tiff
# Processed file: 009-3196-mon_ROI_046_mask.tiff
# Processed file: 009-3406-mon_ROI_003_mask.tiff
# Processed file: 009-3202-mon_ROI_332_mask.tiff
# Processed file: 005-0250-mon_ROI_033_mask.tiff
# Processed file: 009-9703-mon_ROI_367_mask.tiff
# Processed file: 010-0505-mon_ROI_178_mask.tiff
# Processed file: 009-9752-mon_ROI_224_mask.tiff
# Processed file: 010-0505-mon_ROI_293_mask.tiff
# Processed file: 010-0119-mon_ROI_360_mask.tiff
# Processed file: 009-9703-mon_ROI_389_mask.tiff
# Processed file: 007-0173-mon_ROI_010_mask.tiff
# Processed file: 009-3196-mon_ROI_557_mask.tiff
# Processed file: 010-1053-mon_ROI_014_mask.tiff
# Processed file: 008-2940-mon_ROI_017_mask.tiff
# Processed file: 008-2913-mon_ROI_047_mask.tiff
# Processed file: 005-0576-mon_ROI_099_mask.tiff
# Processed file: 010-1053-mon_ROI_001_mask.tiff
# Processed file: 009-3202-mon_ROI_362_mask.tiff
# Processed file: 009-3196-mon_ROI_453_mask.tiff
# Processed file: 009-3202-mon_ROI_301_mask.tiff
# Processed file: 009-3266-mon_ROI_010_mask.tiff
# Processed file: 009-3202-mon_ROI_337_mask.tiff
# Processed file: 009-3220-mon_ROI_296_mask.tiff
# Processed file: 010-0073-mon_ROI_744_mask.tiff
# Processed file: 008-2913-mon_ROI_011_mask.tiff
# Processed file: 008-7515-mon_ROI_036_mask.tiff
# Processed file: 010-0790-mon_ROI_641_mask.tiff
# Processed file: 009-3196-mon_ROI_370_mask.tiff
# Processed file: 009-3193-mon_ROI_037_mask.tiff
# Processed file: 010-0073-mon_ROI_506_mask.tiff
# Processed file: 007-0326-mon_ROI_028_mask.tiff
# Processed file: 010-0505-mon_ROI_157_mask.tiff
# Processed file: 005-0250-mon_ROI_189_mask.tiff
# Processed file: 007-0295-mon_ROI_011_mask.tiff
# Processed file: 009-3196-mon_ROI_465_mask.tiff
# Processed file: 009-3406-mon_ROI_053_mask.tiff
# Processed file: 009-3196-mon_ROI_145_mask.tiff
# Processed file: 009-3247-mon_ROI_105_mask.tiff
# Processed file: 007-0326-mon_ROI_030_mask.tiff
# Processed file: 008-7429-mon_ROI_015_mask.tiff
# Processed file: 009-3337-mon_ROI_040_mask.tiff
# Processed file: 009-3347-mon_ROI_011_mask.tiff
# Processed file: 009-9703-mon_ROI_037_mask.tiff
# Processed file: 008-7564-mon_ROI_044_mask.tiff
# Processed file: 010-0790-mon_ROI_227_mask.tiff
# Processed file: 009-3406-mon_ROI_016_mask.tiff
# Processed file: 010-0073-mon_ROI_587_mask.tiff
# Processed file: 009-3196-mon_ROI_483_mask.tiff
# Processed file: 007-0360-mon_ROI_021_mask.tiff
# Processed file: 010-0790-mon_ROI_769_mask.tiff
# Processed file: 010-0073-mon_ROI_164_mask.tiff
# Processed file: 008-7429-mon_ROI_076_mask.tiff
# Processed file: 010-0790-mon_ROI_123_mask.tiff
# Processed file: 009-9703-mon_ROI_318_mask.tiff
# Processed file: 009-3196-mon_ROI_150_mask.tiff
# Processed file: 009-3202-mon_ROI_522_mask.tiff
# Processed file: 009-3193-mon_ROI_171_mask.tiff
# Processed file: 010-0790-mon_ROI_557_mask.tiff
# Processed file: 010-0896-mon_ROI_023_mask.tiff
# Processed file: 009-3196-mon_ROI_023_mask.tiff
# Processed file: 010-0119-mon_ROI_256_mask.tiff
# Processed file: 009-3266-mon_ROI_090_mask.tiff
# Processed file: 009-3193-mon_ROI_193_mask.tiff
# Processed file: 009-3247-mon_ROI_103_mask.tiff
# Processed file: 009-9703-mon_ROI_230_mask.tiff
# Processed file: 005-0250-mon_ROI_218_mask.tiff
# Processed file: 010-0119-mon_ROI_443_mask.tiff
# Processed file: 010-0119-mon_ROI_625_mask.tiff
# Processed file: 007-1035-mon_ROI_006_mask.tiff
# Processed file: 009-3220-mon_ROI_491_mask.tiff
# Processed file: 010-0896-mon_ROI_069_mask.tiff
# Processed file: 008-2935-mon_ROI_012_mask.tiff
# Processed file: 009-3220-mon_ROI_146_mask.tiff
# Processed file: 009-3220-mon_ROI_450_mask.tiff
# Processed file: 010-0790-mon_ROI_513_mask.tiff
# Processed file: 005-0804-mon_ROI_045_mask.tiff
# Processed file: 007-0876-mon_ROI_022_mask.tiff
# Processed file: 009-3196-mon_ROI_555_mask.tiff
# Processed file: 008-3207-mon_ROI_049_mask.tiff
# Processed file: 009-9703-mon_ROI_215_mask.tiff
# Processed file: 008-7429-mon_ROI_005_mask.tiff
# Processed file: 007-0084-mon_ROI_063_mask.tiff
# Processed file: 010-0505-mon_ROI_202_mask.tiff
# Processed file: 010-0790-mon_ROI_597_mask.tiff
# Processed file: 005-0354-mon_ROI_032_mask.tiff
# Processed file: 009-3193-mon_ROI_079_mask.tiff
# Processed file: 009-3406-mon_ROI_000_mask.tiff
# Processed file: 009-3196-mon_ROI_289_mask.tiff
# Processed file: 008-3340-mon_ROI_025_mask.tiff
# Processed file: 010-1208-mon_ROI_000_mask.tiff
# Processed file: 007-0360-mon_ROI_012_mask.tiff
# Processed file: 009-3337-mon_ROI_080_mask.tiff
# Processed file: 010-0119-mon_ROI_615_mask.tiff
# Processed file: 010-0119-mon_ROI_414_mask.tiff
# Processed file: 010-0790-mon_ROI_678_mask.tiff
# Processed file: 010-1008-mon_ROI_010_mask.tiff
# Processed file: 009-3343-mon_ROI_029_mask.tiff
# Processed file: 010-1461-mon_ROI_056_mask.tiff
# Processed file: 009-3202-mon_ROI_024_mask.tiff
# Processed file: 010-0790-mon_ROI_261_mask.tiff
# Processed file: 010-0119-mon_ROI_560_mask.tiff
# Processed file: 009-3347-mon_ROI_017_mask.tiff
# Processed file: 008-3332-mon_ROI_002_mask.tiff
# Processed file: 010-0073-mon_ROI_182_mask.tiff
# Processed file: 010-0999-mon_ROI_021_mask.tiff
# Processed file: 005-0309-mon_ROI_017_mask.tiff
# Processed file: 005-0405-mon_ROI_069_mask.tiff
# Processed file: 009-9703-mon_ROI_058_mask.tiff
# Processed file: 010-0790-mon_ROI_301_mask.tiff
# Processed file: 008-7568-mon_ROI_005_mask.tiff
# Processed file: 009-3202-mon_ROI_492_mask.tiff
# Processed file: 009-3229-mon_ROI_158_mask.tiff
# Processed file: 010-0505-mon_ROI_308_mask.tiff
# Processed file: 008-3148-mon_ROI_041_mask.tiff
# Processed file: 010-0073-mon_ROI_220_mask.tiff
# Processed file: 010-0119-mon_ROI_129_mask.tiff
# Processed file: 010-0073-mon_ROI_802_mask.tiff

# %%
# =============================
# 4. Save Features to CSV
# =============================
df = pd.DataFrame(all_features)
df.to_csv("roi_shape_features.csv", index=False)
print(f"Saved {len(df)} feature rows to 'roi_shape_features.csv'")
